# %% [markdown]
# See the data

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("mock_data.csv")
# load the data into a dataframe

# %%
df.head() # display the first rows
df.info() # get summery

# %%
df.isnull().sum()
# get missing values

# %%
df('department').unique()

# %% [markdown]
# Data cleaning

# %%
print("handling missing numeric values")
print("records with missing values before filling")
print(df[df['age'].isnull()][['age', 'salary', 'department']])
